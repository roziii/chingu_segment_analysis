# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_transactions = pd.read_csv('./data/cleaned_data/transactions.csv')

# %%
def show_distribution(df):
    # Loop through each column
    for col in df.columns:
        print(f"\n--- Column: {col} ---")
        if pd.api.types.is_numeric_dtype(df[col]):
            print(df[col].describe())
            df[col].hist(bins=10)
            plt.title(f'Distribution of {col}')
            plt.xlabel(col)
            plt.ylabel('Frequency')
            plt.show()
        elif pd.api.types.is_categorical_dtype(df[col]) or df[col].dtype == object:
            print(df[col].value_counts(dropna=False))
            df[col].value_counts(dropna=False).plot(kind='bar')
            plt.title(f'Frequency of {col}')
            plt.xlabel(col)
            plt.ylabel('Count')
            plt.xticks(rotation = 45)
            plt.show()

# %%
show_distribution(df_transactions)
# Out:
# --- Column: Unique ID ---
# Unique ID
# 5387991b8a99a8c31f69e5bf40aa4f1c    23
# 6dfda0f5b98594883081641050e194f6    17
# ec16654715192e1be051404870107589    17
# 524a699715291934292e574fe296d37d    16
# 5f7f81aa7fcbed4aae25a76ebaa958fb    16
#                                     ..
# 8a4306ee2b5e36740d935f275b516bc1     1
# ab2d19833d8410a9c93a326b91d2e29d     1
# 9ad3ffee193ca5a5daa2d7b2a0e2eb98     1
# 10771b5a15f096c4a4952aae8877bcf0     1
# 9f12bb87f5b320d30d0df97d1ad1b41f     1
# Name: count, Length: 353, dtype: int64
# --- Column: Transaction Date ---
# Transaction Date
# 2024-10-21    11
# 2024-12-16    10
# 2024-08-18     9
# 2025-02-18     8
# 2024-12-18     8
#               ..
# 2025-02-23     1
# 2022-08-22     1
# 2025-02-26     1
# 2025-02-28     1
# 2025-03-02     1
# Name: count, Length: 409, dtype: int64
# --- Column: Subscription Status ---
# Subscription Status
# Active           343
# Unknown          339
# Ended            184
# Active,Active     11
# Active,Ended       1
# Ended,Ended        1
# Name: count, dtype: int64
# --- Column: Payment Source ---
# Payment Source
# DISCORD            501
# STRIPE             192
# BUY ME A COFFEE    171
# SPREADSHOP           7
# GOFUNDME             3
# SCRIMBA              3
# TAX REFUND           2
# Name: count, dtype: int64
# --- Column: Product ---
# Product
# SUBSCRIPTION - Junior Professional    475
# DONATION                              174
# PRODUCT - Voyage Certificate          153
# SUBSCRIPTION - Professional            48
# SUBSCRIPTION - Senior Professional     16
# MERCHANDISE                             7
# AFFILIATE                               3
# Unknown                                 2
# ADJUSTMENT                              1
# Name: count, dtype: int64
# --- Column: Certificate Voyage ---
# Certificate Voyage
# No Certificate       722
# V52                   32
# V47                   29
# V51                   24
# V53                   20
# V49                   19
# V50                   19
# V48                   11
# Available for use      3
# Name: count, dtype: int64
# --- Column: Payment Amount ---
# count    879.000000
# mean       8.349943
# std       20.317198
# min        0.000000
# 25%        2.990000
# 50%        2.990000
# 75%        5.000000
# max      278.560000
# Name: Payment Amount, dtype: float64
# --- Column: Transaction Fee ---
# count    879.000000
# mean       0.506633
# std        0.520145
# min        0.000000
# 25%        0.300000
# 50%        0.390000
# 75%        0.470000
# max        6.100000
# Name: Transaction Fee, dtype: float64
# --- Column: Net Payment ---
# count    879.000000
# mean       7.843311
# std       20.029156
# min       -0.300000
# 25%        2.690000
# 50%        2.690000
# 75%        4.550000
# max      278.560000
# Name: Net Payment, dtype: float64
# --- Column: Refund Amount ---
# count    879.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: Refund Amount, dtype: float64
# --- Column: Credits Purchased ---
# count    879.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: Credits Purchased, dtype: float64

# %%
df_applications = pd.read_csv('./data/cleaned_data/applications.csv')

# %%
show_distribution(df_applications)
# Out:
# --- Column: Unique ID ---
# Unique ID
# dadffe486c63fc05d8b3afee2c4dc132    2
# d41d8cd98f00b204e9800998ecf8427e    2
# 76d2e3b5ccc875aa508da1ff60345cfc    2
# c918a2a4f9602562aa70b7cf8a55fc3e    2
# a862a5473ec839d39f9470086810ee6a    2
#                                    ..
# 4e6171a4a188e8be6e6dbadd5ef4a91b    1
# ed59bc3c092373f8dd76815ecfad5ff3    1
# 59c4b62b3dfb5360b27048ad2e9be7aa    1
# 7f8672a6dc7be69c51e92e77ae9ebc17    1
# 377bb89d96a2129aec4ec0ea7f789893    1
# Name: count, Length: 9278, dtype: int64
# --- Column: Subscription Status ---
# Subscription Status
# Active          8740
# Unsubscribed     529
# NaN               19
# Name: count, dtype: int64
# --- Column: Subscription Status DT ---
# Subscription Status DT
# 2022-06-23    57
# 2025-02-02    38
# 2023-10-31    35
# 2024-10-10    34
# 2023-12-01    34
#               ..
# 2019-11-22     1
# 2019-10-16     1
# 2019-11-23     1
# 2019-11-27     1
# 2019-11-28     1
# Name: count, Length: 1603, dtype: int64
# --- Column: Voyage Role ---
# Voyage Role
# Developer         6521
# Data Scientist     686
# Product Owner      681
# Unknown            641
# UI/UX Designer     563
# Scrum Master       196
# Name: count, dtype: int64
# --- Column: Gender ---
# Gender
# MALE                 6258
# FEMALE               2799
# PREFER NOT TO SAY     152
# NON-BINARY             53
# TRANS                  22
# OTHER                   4
# Name: count, dtype: int64
# --- Column: Goal ---
# Goal
# GAIN EXPERIENCE                  5015
# ACCELERATE LEARNING              1825
# NETWORK WITH SHARED GOALS         967
# GET OUT OF TUTORIAL PURGATORY     925
# OTHER                             324
# Unknown                           232
# Name: count, dtype: int64
# --- Column: Source ---
# Source
# PERSONAL NETWORK                 2199
# Google Search                    1514
# LinkedIn                          882
# OTHER_Other                       753
# FREE CODE CAMP FORUM              501
# YOUTUBE                           467
# MEDIUM                            428
# Twitter                           370
# DEV.TO                            323
# Reddit                            304
# Tiktok                            202
# OTHER_Discord                     185
# NaN                               172
# OTHER_Blog or Website             170
# Instagram                         135
# Facebook                          110
# The Job Hackers                    92
# OTHER_Bootcamp Recommendation      91
# Slack                              78
# Scrimba                            69
# OTHER_ChatGPT Suggestion           66
# OTHER_Course or Coding School      63
# OTHER_Podcast                      59
# GitHub                             27
# OTHER_Work or Career Advisor       21
# DEV                                 5
# Nigeria                             1
# FLUTTER EXPLAINED                   1
# Name: count, dtype: int64
# --- Column: Country name (from Country) ---
# Country name (from Country)
# United States    2493
# India             841
# NaN               794
# Nigeria           546
# Canada            473
#                  ...
# Panama              1
# Costa Rica          1
# Slovenia            1
# Timor-Leste         1
# Liberia             1
# Name: count, Length: 171, dtype: int64
# --- Column: Voyage (from Voyage Signups) ---
# Voyage (from Voyage Signups)
# NaN                    7076
# V45                     151
# V43                     130
# V44                     111
# V40                     106
#                        ...
# V??,V??,V53               1
# V51,V53,V54               1
# V51,V53,V52,V53,V54       1
# V51,V51,V53               1
# V51,V54                   1
# Name: count, Length: 398, dtype: int64
# --- Column: Application Age in Days ---
# count    9274.000000
# mean      688.891417
# std       434.070650
# min         0.000000
# 25%       371.000000
# 50%       630.500000
# 75%       978.000000
# max      1975.000000
# Name: Application Age in Days, dtype: float64
# --- Column: Application Day-of-Week ---
# Application Day-of-Week
# 3. Tuesday      1512
# 5. Thursday     1475
# 4. Wednesday    1465
# 2. Monday       1394
# 6. Friday       1240
# 1. Sunday       1149
# 7. Saturday     1038
# #ERROR!           12
# NaN                2
# 2023-12-08         1
# Name: count, dtype: int64
# --- Column: Day-of-Week No ---
# count    9274.000000
# mean        4.144598
# std        21.051239
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         5.000000
# max      2023.000000
# Name: Day-of-Week No, dtype: float64
# --- Column: No. Voyages Started ---
# count    9285.000000
# mean        0.382337
# std         0.943966
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        16.000000
# Name: No. Voyages Started, dtype: float64
# --- Column: Application Date ---
# Application Date
# 2024-02-11    39
# 2021-10-21    33
# 2024-10-10    32
# 2023-10-31    31
# 2023-10-30    29
#               ..
# 2020-01-23     1
# 2020-01-22     1
# 2020-01-19     1
# 2025-01-18     1
# 2025-01-16     1
# Name: count, Length: 1634, dtype: int64
# --- Column: voyages ---
# voyages
# NaN                                    7076
# ['V45']                                 151
# ['V43']                                 130
# ['V44']                                 111
# ['V40']                                 106
#                                        ...
# ['V??', 'V??', 'V53']                     1
# ['V51', 'V53', 'V54']                     1
# ['V51', 'V53', 'V52', 'V53', 'V54']       1
# ['V51', 'V51', 'V53']                     1
# ['V51', 'V54']                            1
# Name: count, Length: 398, dtype: int64
