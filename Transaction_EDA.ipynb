# %%
import sys
import os
import pandas as pd 
import numpy as np 
# Add the 'modules' folder to the Python path
sys.path.append(os.path.abspath('./modules'))

# %%
from Transaction_Cleaner import DataCleaner_Transactions
from EDA import EDA

# %%
sys.path.remove(os.path.abspath('./modules'))
data_cleaner_transactions = DataCleaner_Transactions('./data/DonationAnalysis-Chingu_RevenueTxns.csv')

# %%
data_cleaner_transactions.convert_numeric_columns()

# %%
data_cleaner_transactions.clean_timestamps()

# %%
data_cleaner_transactions.apply_subscription_status_cleaning()

# %%
data_cleaner_transactions.apply_currency_update()

# %%
data_cleaner_transactions.describe_df()
# Out:
#                           Unique ID Transaction Date Subscription Status  \
# 0  d41d8cd98f00b204e9800998ecf8427e              NaT     no-subscription
# 1  fff1b532fb511f1ade207c7f213b1937              NaT              active
# 2  fd9cde9bdb0957f27b1421d2fa34d132              NaT              active
# 3  dadffe486c63fc05d8b3afee2c4dc132              NaT              active
# 4  d41d8cd98f00b204e9800998ecf8427e              NaT     no-subscription
# 5  d41d8cd98f00b204e9800998ecf8427e              NaT     no-subscription
# 6  9377c7a85233065fcab7834ef14ef7a8              NaT              active
# 7  9639a8028a06a8e6435f5fea20e96ce8       2022-08-22     no-subscription
# 8  39568d99c5ee4923a0e8ac3bd917845b       2022-08-29     no-subscription
# 9  d41d8cd98f00b204e9800998ecf8427e       2022-08-30     no-subscription
#
#           Payee Name   Payment Source     Product Certificate Voyage  \
# 0                NaN              NaN         NaN                NaN
# ...
